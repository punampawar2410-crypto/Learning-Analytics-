# %%
# -----------------------------------
# DIMENSIONALITY REDUCTION USING PCA
# -----------------------------------

import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA

# -----------------------------------
# 1. LOAD DATASET
# -----------------------------------
data = pd.read_csv("data.csv", sep=';')

# Clean column names
data.columns = data.columns.str.strip()

print("Original Shape of Dataset:", data.shape)

# -----------------------------------
# 2. HANDLE MISSING VALUES
# -----------------------------------
data.fillna(data.mean(numeric_only=True), inplace=True)

# -----------------------------------
# 3. ENCODE CATEGORICAL VARIABLES
# -----------------------------------
le = LabelEncoder()

categorical_columns = [
    'Gender',
    'Marital status',
    'Daytime/evening attendance',
    'Displaced',
    'Educational special needs',
    'Debtor',
    'Tuition fees up to date',
    'Scholarship holder',
    'International'
]

for col in categorical_columns:
    if col in data.columns:
        data[col] = le.fit_transform(data[col])

# -----------------------------------
# 4. SEPARATE FEATURES AND TARGET
# -----------------------------------
X = data.drop('Target', axis=1)
y = data['Target']

# -----------------------------------
# 5. FEATURE SCALING
# -----------------------------------
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# -----------------------------------
# 6. APPLY PCA
# -----------------------------------
# Reduce to 2 principal components
pca = PCA(n_components=2)

X_pca = pca.fit_transform(X_scaled)

# -----------------------------------
# 7. RESULTS
# -----------------------------------
print("\nReduced Shape after PCA:", X_pca.shape)

print("\nExplained Variance Ratio:")
print(pca.explained_variance_ratio_)

print("\nTotal Variance Explained:",
      sum(pca.explained_variance_ratio_))
# Out:
# Original Shape of Dataset: (4424, 37)
#
# Reduced Shape after PCA: (4424, 2)
#
# Explained Variance Ratio:
# [0.17666395 0.0988699 ]
#
# Total Variance Explained: 0.27553384340420345
